# %%
#Import Necessary Library's
import pandas as pd
import json
from pathlib import Path

# %%
#Import Data
data_folder = Path("./Data/")

FreedomFile = data_folder / "economic_freedom_index2019_data.csv"
economicFreedomDF = pd.read_csv(FreedomFile,encoding='latin-1')
economicFreedomDF2 = economicFreedomDF.set_index("Country Name")
economicFreedomDF2
# Out:
#               CountryID      WEBNAME                        Region  \
# Country Name
# Afghanistan           1  Afghanistan                  Asia-Pacific
# Albania               2      Albania                        Europe
# Algeria               3      Algeria  Middle East and North Africa
# Angola                4       Angola            Sub-Saharan Africa
# Argentina             5    Argentina                      Americas
# ...                 ...          ...                           ...
# Venezuela           179    Venezuela                      Americas
# Vietnam             180      Vietnam                  Asia-Pacific
# Yemen               181        Yemen  Middle East and North Africa
# Zambia              182       Zambia            Sub-Saharan Africa
# Zimbabwe            183     Zimbabwe            Sub-Saharan Africa
#
#               World Rank  Region Rank  2019 Score  Property Rights  \
# Country Name
# Afghanistan        152.0         39.0        51.5             19.6
# Albania             52.0         27.0        66.5             54.8
# Algeria            171.0         14.0        46.2             31.6
# Angola             156.0         33.0        50.6             35.9
# Argentina          148.0         26.0        52.2             47.8
# ...                  ...          ...         ...              ...
# Venezuela          179.0         32.0        25.9              7.6
# Vietnam            128.0         30.0        55.3             49.8
# Yemen                NaN          NaN         NaN             19.6
# Zambia             138.0         27.0        53.6             45.0
# Zimbabwe           175.0         45.0        40.4             29.7
#
#               Judical Effectiveness  Government Integrity  Tax Burden  ...  \
# Country Name                                                           ...
# Afghanistan                    29.6                  25.2        91.7  ...
# Albania                        30.6                  40.4        86.3  ...
# Algeria                        36.2                  28.9        76.4  ...
# Angola                         26.6                  20.5        83.9  ...
# Argentina                      44.5                  33.5        69.3  ...
# ...                             ...                   ...         ...  ...
# Venezuela                      13.1                   7.9        74.7  ...
# Vietnam                        40.3                  34.0        79.7  ...
# Yemen                          22.2                  20.3         NaN  ...
# Zambia                         35.6                  32.3        72.3  ...
# Zimbabwe                       24.8                  15.8        62.3  ...
#
#                   Country  Population (Millions)  GDP (Billions, PPP)  \
# Country Name
# Afghanistan   Afghanistan                   35.5               $69.6
# Albania           Albania                    2.9               $36.0
# Algeria           Algeria                   41.5              $632.9
# Angola             Angola                   28.2              $190.3
# Argentina       Argentina                   44.1              $920.2
# ...                   ...                    ...                  ...
# Venezuela       Venezuela                   31.4              $380.7
# Vietnam           Vietnam                   93.6              $647.4
# Yemen               Yemen                   30.0               $38.6
# Zambia             Zambia                   17.2               $68.9
# Zimbabwe         Zimbabwe                   14.9               $34.0
#
#               GDP Growth Rate (%)  5 Year GDP Growth Rate (%)  \
# Country Name
# Afghanistan                   2.5                         2.9
# Albania                       3.9                         2.5
# Algeria                       2.0                         3.1
# Angola                        0.7                         2.9
# Argentina                     2.9                         0.7
# ...                           ...                         ...
# Venezuela                   -14.0                        -7.8
# Vietnam                       6.8                         6.2
# Yemen                       -13.8                       -16.1
# Zambia                        3.6                         4.0
# Zimbabwe                      3.0                         2.6
#
#               GDP per Capita (PPP)  Unemployment (%)  Inflation (%)  \
# Country Name
# Afghanistan                 $1,958               8.8            5.0
# Albania                    $12,507              13.9            2.0
# Algeria                    $15,237              10.0            5.6
# Angola                      $6,753               8.2           31.7
# Argentina                  $20,876               8.7           25.7
# ...                            ...               ...            ...
# Venezuela                  $12,114               7.7         1087.5
# Vietnam                     $6,913               2.1            3.5
# Yemen                       $1,287              14.0            4.9
# Zambia                      $3,996               7.8            6.6
# Zimbabwe                    $2,283               5.0            1.3
#
#               FDI Inflow (Millions)  Public Debt (% of GDP)
# Country Name
# Afghanistan                    53.9                     7.3
# Albania                     1,119.1                    71.2
# Algeria                     1,203.0                    25.8
# Angola                     -2,254.5                    65.3
# Argentina                  11,857.0                    52.6
# ...                             ...                     ...
# Venezuela                     -68.0                    34.9
# Vietnam                    14,100.0                    58.2
# Yemen                        -269.9                   141.0
# Zambia                      1,091.2                    62.2
# Zimbabwe                      289.4                    78.4
#
# [186 rows x 33 columns]
